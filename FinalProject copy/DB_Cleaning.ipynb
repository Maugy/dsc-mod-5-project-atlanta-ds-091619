# %%
import pandas as pd

# %%
raw = pd.read_csv('total_data_date.csv')
raw.head()
# Out:
#                              title              company  \
# 0                   Data Scientist             Esurance
# 1                   DATA SCIENTIST              Walmart
# 2                   Data Scientist               Kohl's
# 3  Staff Data Scientist (GEC11903)    Walmart eCommerce
# 4               Sr. Data Scientist  Silicon Valley Bank
#
#                   location                                        description  \
# 0  San Francisco, CA 94105  [     Summary       Esurance is looking for a ...
# 1      Sunnyvale, CA 94087  [     Position Description    Data Scientist i...
# 2       Milpitas, CA 95035  [  Interpret and apply data analyses and expla...
# 3      Sunnyvale, CA 94087  [     Position Description      Understands an...
# 4      Palo Alto, CA 94304  [       Silicon Valley Bank is the market lead...
#
#          date
# 0  12-01-2019
# 1  12-01-2019
# 2  12-01-2019
# 3  12-01-2019
# 4  12-01-2019

# %%
raw
# Out:
#                                  title                   company  \
# 0                       Data Scientist                  Esurance
# 1                       DATA SCIENTIST                   Walmart
# 2                       Data Scientist                    Kohl's
# 3      Staff Data Scientist (GEC11903)         Walmart eCommerce
# 4                   Sr. Data Scientist       Silicon Valley Bank
# ...                                ...                       ...
# 19716                    Data Engineer              OneGlobe LLC
# 19717             Senior Data Engineer          Augeo FI Loyalty
# 19718             Senior Data Engineer  Liberty Mutual Insurance
# 19719                    Data Engineer    Noetic Strategies Inc.
# 19720        Sr Data Engineer - Hadoop              Anthem, Inc.
#
#                       location  \
# 0      San Francisco, CA 94105
# 1          Sunnyvale, CA 94087
# 2           Milpitas, CA 95035
# 3          Sunnyvale, CA 94087
# ...

# %%
dropped = raw.drop_duplicates(subset=['description'], keep='first')

# %%
dropped
# Out:
#                                            title  \
# 0                                 Data Scientist
# 1                                 DATA SCIENTIST
# 2                                 Data Scientist
# 3                Staff Data Scientist (GEC11903)
# 4                             Sr. Data Scientist
# ...                                          ...
# 19575                          Big Data Engineer
# 19583                              Data Engineer
# 19702                       Senior Data Engineer
# 19707  Senior Data Engineer & Solution Architect
# 19709                       Senior Data Engineer
#
#                                company                 location  \
# 0                             Esurance  San Francisco, CA 94105
# 1                              Walmart      Sunnyvale, CA 94087
# 2                               Kohl's       Milpitas, CA 95035
# 3                    Walmart eCommerce      Sunnyvale, CA 94087
# ...

# %%
raw['description'].value_counts()
# Out:
# None                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  
# ...

# %%
cleaned = dropped.reset_index(drop=True)

# %%
cleaned
# Out:
#                                           title  \
# 0                                Data Scientist
# 1                                DATA SCIENTIST
# 2                                Data Scientist
# 3               Staff Data Scientist (GEC11903)
# 4                            Sr. Data Scientist
# ...                                         ...
# 5129                          Big Data Engineer
# 5130                              Data Engineer
# 5131                       Senior Data Engineer
# 5132  Senior Data Engineer & Solution Architect
# 5133                       Senior Data Engineer
#
#                               company                 location  \
# 0                            Esurance  San Francisco, CA 94105
# 1                             Walmart      Sunnyvale, CA 94087
# 2                              Kohl's       Milpitas, CA 95035
# 3                   Walmart eCommerce      Sunnyvale, CA 94087
# 4                 Silicon Valley Bank      Palo Alto, CA 94304
# ...

# %%
cleaned.to_csv('/users/dmauger/Flatiron/FinalProject/' + 'cleaned_df.csv', mode='w', header=True, encoding='utf-8', index=False)

# %%
df = pd.read_csv('cleaned_df.csv')
df
# Out:
#                                           title  \
# 0                                Data Scientist
# 1                                DATA SCIENTIST
# 2                                Data Scientist
# 3               Staff Data Scientist (GEC11903)
# 4                            Sr. Data Scientist
# ...                                         ...
# 5129                          Big Data Engineer
# 5130                              Data Engineer
# 5131                       Senior Data Engineer
# 5132  Senior Data Engineer & Solution Architect
# 5133                       Senior Data Engineer
#
#                               company                 location  \
# 0                            Esurance  San Francisco, CA 94105
# 1                             Walmart      Sunnyvale, CA 94087
# 2                              Kohl's       Milpitas, CA 95035
# 3                   Walmart eCommerce      Sunnyvale, CA 94087
# 4                 Silicon Valley Bank      Palo Alto, CA 94304
# ...

# %%
ind_df = pd.read_csv('demo_indeed_webscrape.csv')
ind_df
# Out:
#                               title  \
# 0                    Data Scientist
# 1                    Data Scientist
# 2                Sr. Data Scientist
# 3     Pharmaceutical Data Scientist
# 4    Data Scientist - Economic Data
# ..                              ...
# 717    Sr. Manager Machine Learning
# 718       Machine Learning Engineer
# 719       Machine Learning Engineer
# 720       Machine Learning Engineer
# 721       Machine Learning Engineer
#
#                                            company            location  \
# 0    Blue Cross Blue Shield of IL, MT, NM, OK & TX         Chicago, IL
# 1         Social Science Research Solutions (SSRS)      Glen Mills, PA
# 2                                    Reef Kitchens         Waltham, MA
# 3                          Pharma RI International  Woodcliff Lake, NJ
# 4                                           Zillow   Seattle, WA 98101
# ..                                             ...                 ...
# ...

# %%
ind_clean = ind_df.drop_duplicates(subset=['description'], keep='first')
ind_clean = ind_clean.reset_index(drop=True)

# %%
ind_clean
# Out:
#                               title  \
# 0                    Data Scientist
# 1                    Data Scientist
# 2                Sr. Data Scientist
# 3     Pharmaceutical Data Scientist
# 4    Data Scientist - Economic Data
# ..                              ...
# 220    Sr. Manager Machine Learning
# 221       Machine Learning Engineer
# 222       Machine Learning Engineer
# 223       Machine Learning Engineer
# 224       Machine Learning Engineer
#
#                                            company            location  \
# 0    Blue Cross Blue Shield of IL, MT, NM, OK & TX         Chicago, IL
# 1         Social Science Research Solutions (SSRS)      Glen Mills, PA
# 2                                    Reef Kitchens         Waltham, MA
# 3                          Pharma RI International  Woodcliff Lake, NJ
# 4                                           Zillow   Seattle, WA 98101
# ..                                             ...                 ...
# ...

# %%
li_df = pd.read_csv('demo_webscrape.csv')

# %%
li_clean = li_df.drop_duplicates(subset=['description'], keep='first')
li_clean = li_clean.reset_index(drop=True)

# %%
li_clean
# Out:
#             title                            company  \
# 0    Data Analyst  The University of Texas at Austin
# 1    Data Analyst                    The Job Network
# 2    Data Analyst                      CodeForce 360
# 3    Data Analyst                      CodeForce 360
# 4    Data Analyst                  Share Local Media
# ..            ...                                ...
# 225  Data Analyst                      DBSI Services
# 226  Data Analyst                         UST Global
# 227  Data Analyst               Clover Network, Inc.
# 228  Data Analyst                            thredUP
# 229  Data Analyst                      Guy Carpenter
#
#                                       location  \
# 0                                Texas, TX, US
# 1                              Seattle, WA, US
# 2                            Worcester, MA, US
# 3                            Charlotte, NC, US
# 4                      New York, United States
# ...

# %%
ind_clean.to_csv('/users/dmauger/Flatiron/FinalProject/' + 'demo_indeed_webscrape.csv', mode='w', header=True, encoding='utf-8', index=False)

# %%
li_clean.to_csv('/users/dmauger/Flatiron/FinalProject/' + 'demo_webscrape.csv', mode='w', header=True, encoding='utf-8', index=False)
